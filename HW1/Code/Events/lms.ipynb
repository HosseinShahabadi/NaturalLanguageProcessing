# %%
import lmstudio as lms

import os
import json

model = lms.llm("gemma-3-4b-persian-v0")

# %%
with open("./cities.csv", "r") as file:
    cities = file.read()

with open("./cities.json", "r") as file:
    cities_dict = json.load(file)

questions = [
    {
        "field": "location.province",
        "question": "استان مربوط به این رویداد جیست؟ (فقط نام استان)",
    },
]

# %%
def update(event: dict, cities, questions: dict, model):
    description = event["description"]

    for question_dict in questions:
        fields = question_dict["field"].split(".")
        question = question_dict["question"]

        answer = model.respond(f"{cities}. {description}. {question}").parsed

        obj = event
        for field in fields[:-1]:
            obj = obj[field]
        obj[fields[-1]] = answer
    return event

# %%
def get_city(event: dict, cities, model):
    if event["location"]["city"] not in ["نامعلوم", "<TBD>"]:
        return event

    question = "شهر مربوط به این رویداد جیست؟ (فقط نام شهر که باید در لیست باشد)"
    answer = model.respond(f"{cities}. {event["description"]}. {question}").parsed

    event["location"]["city"] = answer

    return event

# %%
def get_latitude_longitude(event: dict, cities, cities_dict, model):
    if (
        event["location"]["coordinates"]["latitude"] != "<TBD"
        and event["location"]["coordinates"]["longitude"] != "<TBD>"
    ):
        return event

    question = "مرکز استان مربوط به این رویداد چیست؟ (فقط نام شهر)"
    answer = model.respond(f"{cities}. {event["description"]}. {question}").parsed

    if answer not in cities_dict:
        return event

    latitude = cities_dict[answer]["coordinates"]["latitude"]
    longitude = cities_dict[answer]["coordinates"]["longitude"]

    event["location"]["coordinates"]["latitude"] = latitude
    event["location"]["coordinates"]["longitude"] = longitude

    return event

# %%
INPUT_ROOT = "./DATASET-V1"
OUTPUT_ROOT = "./DATASET-V2"

os.makedirs(OUTPUT_ROOT, exist_ok=True)

for dirpath, dirnames, filenames in os.walk(INPUT_ROOT):
    relative_path = os.path.relpath(dirpath, INPUT_ROOT)
    output_dirpath = os.path.join(OUTPUT_ROOT, relative_path)

    os.makedirs(output_dirpath, exist_ok=True)

    for filename in filenames:
        input_path = os.path.join(dirpath, filename)

        with open(input_path, "r", encoding="utf-8") as file:
            event = json.load(file)

        event = update(event, "", questions, model)
        event = get_city(event, "", model)
        event = get_latitude_longitude(event, "", cities_dict, model)

        output_path = os.path.join(output_dirpath, filename)
        with open(output_path, "w", encoding="utf-8") as file:
            json.dump(event, file, ensure_ascii=False, indent=4)

        print(f"✅ successfully processed {output_path}")
# Out:
# ✅ successfully processed ./DATASET-V2/BIRTH/115.json
# ✅ successfully processed ./DATASET-V2/BIRTH/050.json
# ✅ successfully processed ./DATASET-V2/BIRTH/142.json
# ✅ successfully processed ./DATASET-V2/BIRTH/007.json
# ✅ successfully processed ./DATASET-V2/BIRTH/011.json
# ✅ successfully processed ./DATASET-V2/BIRTH/103.json
# ✅ successfully processed ./DATASET-V2/BIRTH/046.json
# ✅ successfully processed ./DATASET-V2/BIRTH/085.json
# ✅ successfully processed ./DATASET-V2/BIRTH/093.json
# ✅ successfully processed ./DATASET-V2/BIRTH/139.json
# ✅ successfully processed ./DATASET-V2/BIRTH/119.json
# ✅ successfully processed ./DATASET-V2/BIRTH/031.json
# ✅ successfully processed ./DATASET-V2/BIRTH/066.json
# ✅ successfully processed ./DATASET-V2/BIRTH/089.json
# ✅ successfully processed ./DATASET-V2/BIRTH/123.json
# ✅ successfully processed ./DATASET-V2/BIRTH/070.json
# ✅ successfully processed ./DATASET-V2/BIRTH/135.json
# ✅ successfully processed ./DATASET-V2/BIRTH/027.json
# ✅ successfully processed ./DATASET-V2/BIRTH/026.json
# ✅ successfully processed ./DATASET-V2/BIRTH/071.json
# ✅ successfully processed ./DATASET-V2/BIRTH/134.json
# ✅ successfully processed ./DATASET-V2/BIRTH/067.json
# ✅ successfully processed ./DATASET-V2/BIRTH/088.json
# ✅ successfully processed ./DATASET-V2/BIRTH/122.json
# ✅ successfully processed ./DATASET-V2/BIRTH/030.json
# ✅ successfully processed ./DATASET-V2/BIRTH/118.json
# ✅ successfully processed ./DATASET-V2/BIRTH/092.json
# ✅ successfully processed ./DATASET-V2/BIRTH/138.json
# ✅ successfully processed ./DATASET-V2/BIRTH/084.json
# ✅ successfully processed ./DATASET-V2/BIRTH/102.json
# ✅ successfully processed ./DATASET-V2/BIRTH/047.json
# ✅ successfully processed ./DATASET-V2/BIRTH/010.json
# ✅ successfully processed ./DATASET-V2/BIRTH/143.json
# ✅ successfully processed ./DATASET-V2/BIRTH/006.json
# ✅ successfully processed ./DATASET-V2/BIRTH/114.json
# ✅ successfully processed ./DATASET-V2/BIRTH/051.json
# ✅ successfully processed ./DATASET-V2/BIRTH/148.json
# ✅ successfully processed ./DATASET-V2/BIRTH/109.json
# ✅ successfully processed ./DATASET-V2/BIRTH/037.json
# ✅ successfully processed ./DATASET-V2/BIRTH/060.json
# ✅ successfully processed ./DATASET-V2/BIRTH/125.json
# ✅ successfully processed ./DATASET-V2/BIRTH/076.json
# ✅ successfully processed ./DATASET-V2/BIRTH/133.json
# ✅ successfully processed ./DATASET-V2/BIRTH/099.json
# ✅ successfully processed ./DATASET-V2/BIRTH/021.json
# ✅ successfully processed ./DATASET-V2/BIRTH/113.json
# ✅ successfully processed ./DATASET-V2/BIRTH/056.json
# ✅ successfully processed ./DATASET-V2/BIRTH/144.json
# ✅ successfully processed ./DATASET-V2/BIRTH/001.json
# ✅ successfully processed ./DATASET-V2/BIRTH/152.json
# ✅ successfully processed ./DATASET-V2/BIRTH/017.json
# ✅ successfully processed ./DATASET-V2/BIRTH/105.json
# ✅ successfully processed ./DATASET-V2/BIRTH/040.json
# ✅ successfully processed ./DATASET-V2/BIRTH/129.json
# ✅ successfully processed ./DATASET-V2/BIRTH/083.json
# ✅ successfully processed ./DATASET-V2/BIRTH/095.json
# ✅ successfully processed ./DATASET-V2/BIRTH/094.json
# ✅ successfully processed ./DATASET-V2/BIRTH/128.json
# ✅ successfully processed ./DATASET-V2/BIRTH/082.json
# ✅ successfully processed ./DATASET-V2/BIRTH/104.json
# ✅ successfully processed ./DATASET-V2/BIRTH/041.json
# ✅ successfully processed ./DATASET-V2/BIRTH/153.json
# ✅ successfully processed ./DATASET-V2/BIRTH/016.json
# ✅ successfully processed ./DATASET-V2/BIRTH/145.json
# ✅ successfully processed ./DATASET-V2/BIRTH/112.json
# ✅ successfully processed ./DATASET-V2/BIRTH/057.json
# ✅ successfully processed ./DATASET-V2/BIRTH/020.json
# ✅ successfully processed ./DATASET-V2/BIRTH/077.json
# ✅ successfully processed ./DATASET-V2/BIRTH/132.json
# ✅ successfully processed ./DATASET-V2/BIRTH/098.json
# ✅ successfully processed ./DATASET-V2/BIRTH/061.json
# ✅ successfully processed ./DATASET-V2/BIRTH/124.json
# ✅ successfully processed ./DATASET-V2/BIRTH/036.json
# ✅ successfully processed ./DATASET-V2/BIRTH/108.json
# ✅ successfully processed ./DATASET-V2/BIRTH/149.json
# ✅ successfully processed ./DATASET-V2/BIRTH/023.json
# ✅ successfully processed ./DATASET-V2/BIRTH/131.json
# ✅ successfully processed ./DATASET-V2/BIRTH/074.json
# ✅ successfully processed ./DATASET-V2/BIRTH/127.json
# ✅ successfully processed ./DATASET-V2/BIRTH/062.json
# ✅ successfully processed ./DATASET-V2/BIRTH/035.json
# ✅ successfully processed ./DATASET-V2/BIRTH/019.json
# ✅ successfully processed ./DATASET-V2/BIRTH/058.json
# ✅ successfully processed ./DATASET-V2/BIRTH/097.json
# ✅ successfully processed ./DATASET-V2/BIRTH/078.json
# ✅ successfully processed ./DATASET-V2/BIRTH/081.json
# ✅ successfully processed ./DATASET-V2/BIRTH/039.json
# ✅ successfully processed ./DATASET-V2/BIRTH/042.json
# ✅ successfully processed ./DATASET-V2/BIRTH/107.json
# ✅ successfully processed ./DATASET-V2/BIRTH/015.json
# ✅ successfully processed ./DATASET-V2/BIRTH/150.json
# ✅ successfully processed ./DATASET-V2/BIRTH/003.json
# ✅ successfully processed ./DATASET-V2/BIRTH/146.json
# ✅ successfully processed ./DATASET-V2/BIRTH/054.json
# ✅ successfully processed ./DATASET-V2/BIRTH/111.json
# ✅ successfully processed ./DATASET-V2/BIRTH/055.json
# ✅ successfully processed ./DATASET-V2/BIRTH/110.json
# ✅ successfully processed ./DATASET-V2/BIRTH/002.json
# ✅ successfully processed ./DATASET-V2/BIRTH/147.json
# ✅ successfully processed ./DATASET-V2/BIRTH/014.json
# ✅ successfully processed ./DATASET-V2/BIRTH/151.json
# ✅ successfully processed ./DATASET-V2/BIRTH/043.json
# ✅ successfully processed ./DATASET-V2/BIRTH/106.json
# ✅ successfully processed ./DATASET-V2/BIRTH/038.json
# ✅ successfully processed ./DATASET-V2/BIRTH/080.json
# ✅ successfully processed ./DATASET-V2/BIRTH/096.json
# ✅ successfully processed ./DATASET-V2/BIRTH/079.json
# ✅ successfully processed ./DATASET-V2/BIRTH/059.json
# ✅ successfully processed ./DATASET-V2/BIRTH/018.json
# ✅ successfully processed ./DATASET-V2/BIRTH/034.json
# ✅ successfully processed ./DATASET-V2/BIRTH/126.json
# ✅ successfully processed ./DATASET-V2/BIRTH/063.json
# ✅ successfully processed ./DATASET-V2/BIRTH/130.json
# ✅ successfully processed ./DATASET-V2/BIRTH/075.json
# ✅ successfully processed ./DATASET-V2/BIRTH/022.json
# ✅ successfully processed ./DATASET-V2/BIRTH/029.json
# ✅ successfully processed ./DATASET-V2/BIRTH/091.json
# ✅ successfully processed ./DATASET-V2/BIRTH/087.json
# ✅ successfully processed ./DATASET-V2/BIRTH/068.json
# ✅ successfully processed ./DATASET-V2/BIRTH/044.json
# ✅ successfully processed ./DATASET-V2/BIRTH/101.json
# ✅ successfully processed ./DATASET-V2/BIRTH/013.json
# ✅ successfully processed ./DATASET-V2/BIRTH/005.json
# ✅ successfully processed ./DATASET-V2/BIRTH/140.json
# ✅ successfully processed ./DATASET-V2/BIRTH/052.json
# ✅ successfully processed ./DATASET-V2/BIRTH/117.json
# ✅ successfully processed ./DATASET-V2/BIRTH/025.json
# ✅ successfully processed ./DATASET-V2/BIRTH/137.json
# ✅ successfully processed ./DATASET-V2/BIRTH/072.json
# ✅ successfully processed ./DATASET-V2/BIRTH/121.json
# ✅ successfully processed ./DATASET-V2/BIRTH/064.json
# ✅ successfully processed ./DATASET-V2/BIRTH/033.json
# ✅ successfully processed ./DATASET-V2/BIRTH/048.json
# ✅ successfully processed ./DATASET-V2/BIRTH/009.json
# ✅ successfully processed ./DATASET-V2/BIRTH/008.json
# ✅ successfully processed ./DATASET-V2/BIRTH/049.json
# ✅ successfully processed ./DATASET-V2/BIRTH/032.json
# ✅ successfully processed ./DATASET-V2/BIRTH/120.json
# ✅ successfully processed ./DATASET-V2/BIRTH/065.json
# ✅ successfully processed ./DATASET-V2/BIRTH/136.json
# ✅ successfully processed ./DATASET-V2/BIRTH/073.json
# ✅ successfully processed ./DATASET-V2/BIRTH/024.json
# ✅ successfully processed ./DATASET-V2/BIRTH/053.json
# ✅ successfully processed ./DATASET-V2/BIRTH/116.json
# ✅ successfully processed ./DATASET-V2/BIRTH/004.json
# ✅ successfully processed ./DATASET-V2/BIRTH/141.json
# ✅ successfully processed ./DATASET-V2/BIRTH/012.json
# ✅ successfully processed ./DATASET-V2/BIRTH/045.json
# ✅ successfully processed ./DATASET-V2/BIRTH/100.json
# ✅ successfully processed ./DATASET-V2/BIRTH/086.json
# ✅ successfully processed ./DATASET-V2/BIRTH/069.json
# ✅ successfully processed ./DATASET-V2/BIRTH/090.json
# ✅ successfully processed ./DATASET-V2/BIRTH/028.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/007.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/011.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/027.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/026.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/030.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/010.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/006.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/021.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/001.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/017.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/016.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/020.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/023.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/019.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/015.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/003.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/002.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/014.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/018.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/022.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/029.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/013.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/005.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/025.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/009.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/008.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/024.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/004.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/012.json
# ✅ successfully processed ./DATASET-V2/JUDICIAL/028.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/115.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/050.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/142.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/007.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/154.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/011.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/103.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/046.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/197.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/178.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/206.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/085.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/210.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/093.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/139.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/181.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/119.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/230.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/158.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/226.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/031.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/174.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/066.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/089.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/123.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/070.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/135.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/027.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/162.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/026.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/163.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/071.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/134.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/067.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/088.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/122.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/030.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/175.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/227.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/159.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/231.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/118.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/180.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/092.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/138.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/211.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/084.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/207.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/196.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/179.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/102.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/047.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/155.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/010.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/143.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/006.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/114.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/051.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/236.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/148.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/109.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/220.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/037.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/172.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/060.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/125.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/076.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/133.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/099.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/021.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/164.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/113.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/056.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/144.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/001.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/152.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/017.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/105.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/040.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/191.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/200.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/129.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/083.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/216.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/095.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/241.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/187.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/168.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/186.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/169.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/240.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/094.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/217.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/128.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/082.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/201.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/190.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/104.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/041.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/153.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/016.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/145.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/112.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/057.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/020.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/165.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/077.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/132.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/098.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/061.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/124.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/036.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/173.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/221.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/108.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/149.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/237.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/166.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/189.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/023.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/218.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/131.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/074.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/127.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/062.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/170.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/035.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/222.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/019.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/234.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/058.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/185.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/243.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/097.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/078.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/214.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/081.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/202.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/193.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/039.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/042.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/107.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/015.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/150.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/003.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/146.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/054.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/111.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/238.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/239.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/055.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/110.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/002.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/147.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/014.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/151.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/043.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/106.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/192.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/038.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/203.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/080.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/215.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/096.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/079.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/242.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/184.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/059.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/235.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/018.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/223.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/171.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/034.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/126.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/063.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/130.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/075.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/219.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/167.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/188.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/022.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/029.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/183.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/245.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/091.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/212.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/087.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/068.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/204.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/195.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/044.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/101.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/228.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/013.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/156.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/005.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/140.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/052.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/117.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/160.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/025.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/137.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/072.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/208.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/121.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/064.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/176.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/033.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/199.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/224.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/048.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/009.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/232.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/233.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/008.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/049.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/225.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/177.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/032.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/198.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/120.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/065.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/209.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/136.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/073.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/161.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/024.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/053.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/116.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/004.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/141.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/012.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/157.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/229.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/045.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/100.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/194.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/205.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/086.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/069.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/213.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/090.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/244.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/028.json
# ✅ successfully processed ./DATASET-V2/CULTURAL/182.json
