# %%
from bs4 import BeautifulSoup
from requests import get

from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait

import time
import os

import json

# %%
BASE_URL = "https://tarikh.inoor.ir/"

SOURCE = 11970
EVENT_TYPES = {"BIRTH": 2, "JUDICIAL": 44, "CULTURAL": 1070}

ROOT = "DATASET-V1"

# %%
def get_events_page(
    event_type: int,
    source: int,
    page_number: int,
    base_url: str = BASE_URL,
    timeout: int = 5,
) -> BeautifulSoup:
    EVENT_PAGE_POSTFIX = "fa/event/list/رویدادها"
    params = {
        "UserLanguage": "fa",
        "EventType": str(event_type),
        "Source": str(source),
        "PageNumber": str(page_number),
    }

    EVENTS_PAGE_URL = f"{base_url}{EVENT_PAGE_POSTFIX}"
    query_string = "&".join(f"{k}={v}" for k, v in params.items())
    url = f"{EVENTS_PAGE_URL}?{query_string}"

    options = webdriver.ChromeOptions()
    options.add_argument("--headless")

    driver = webdriver.Chrome(options=options)

    try:
        driver.get(url)
        WebDriverWait(driver, timeout)

        return BeautifulSoup(driver.page_source, "html.parser")
    finally:
        driver.quit()

# %%
def get_events_links(events: BeautifulSoup) -> list[str]:
    return [
        a.get("href").split("?")[0]
        for a in events.select("div.event-title a")
        if a and a.get("href")
    ]

# %%
def get_event_page(
    link: str, base_url: str = BASE_URL, timeout: int = 5
) -> BeautifulSoup:
    url = f"{base_url}{link[1:]}"

    options = webdriver.ChromeOptions()
    options.add_argument("--headless")

    with webdriver.Chrome(options=options) as driver:
        driver.get(url)
        WebDriverWait(driver, timeout)

        return BeautifulSoup(driver.page_source, "html.parser")

# %%
def to_persian_digits(s: str) -> str:
    TRANSLATION_TABLE = str.maketrans("0123456789", "۰۱۲۳۴۵۶۷۸۹")
    return s.translate(TRANSLATION_TABLE)

# %%
def sanitize(s: str) -> str:
    unwanted_chars = ["؟", "#", "$", "%", "&", "*", "(", ")"]
    for char in unwanted_chars:
        s = s.replace(char, "")
    return s

# %%
def get_location_name(s: str) -> str:
    return s.split("(")[0].strip()

# %%
def remove_non_digit_chars(s: str) -> str:
    return "".join(filter(str.isdigit, s))

# %%
def process_pages(type: str, pages):
    os.makedirs(f"./{ROOT}", exist_ok=True)
    os.makedirs(f"./{ROOT}/{type}", exist_ok=True)

    locations = json.load(open("./cities.json"))

    global_idx = 1

    processed_links = set()

    for page_number in pages:
        page = get_events_page(
            event_type=EVENT_TYPES[type],
            source=SOURCE,
            page_number=page_number,
        )

        links = get_events_links(page)

        for link in links:
            if link in processed_links:
                continue
            processed_links.add(link)

            try:
                event = get_event_page(link, timeout=2)

                title = event.find("h1", class_="event-title").text.strip()
                comment = event.find("h3", class_="event-comment").text.strip()
                description = event.find("p", class_="report-text").text.strip()
                source = event.find("div", class_="report-source").text.strip()

                row_values = event.select(".row-value")
                try:
                    year = int(remove_non_digit_chars(row_values[0].text))
                    year = year - ((year * 11) // 365)
                except:
                    year = "<TBD>"

                try:
                    city = " ".join(row_values[2].text.replace("\n", "").split())
                    city = get_location_name(to_persian_digits(city))
                except:
                    city = "<TBD>"

                # save data
                location = locations.get(city, -1)

                with open(
                    f"./{ROOT}/{type}/{global_idx:03d}.json", "w", encoding="utf-8"
                ) as f:
                    json.dump(
                        {
                            "title": to_persian_digits(comment),
                            "description": to_persian_digits(description),
                            "period": {
                                "start_year": to_persian_digits(str(year)),
                                "end_year": to_persian_digits(str(year)),
                            },
                            "location": (
                                {
                                    "province": "<TBD>",
                                    "city": to_persian_digits(city),
                                    "coordinates": {
                                        "latitude": "<TBD>",
                                        "longitude": "<TBD>",
                                    },
                                }
                                if location == -1
                                else location
                            ),
                            "refrences": {
                                "title": to_persian_digits(source),
                                "author": "حسن فراهانی",
                                "year": "۱۳۸۵",
                            },
                            "source": {
                                "title": to_persian_digits(title),
                                "author": "پایگاه جامع تاریخ",
                                "url": f"{BASE_URL}{link[1:]}",
                            },
                        },
                        f,
                        ensure_ascii=False,
                        indent=4,
                    )

                print(f"✅ {global_idx:03d} - {link}")
                time.sleep(0.5)

                global_idx += 1
            except:
                print(f"☹️ ERROR PROCESSING LINK: {link}")

# %%
process_pages('BIRTH', range(1, 7 + 1))
# Out:
# ✅ 001 - /fa/event/page/1KKKKM/ولادت_شیخ_عبد_النبی_نوری
# ✅ 002 - /fa/event/page/2E0E8I/ولادت_جهانشاه_خان_امیر_افشار
# ✅ 003 - /fa/event/page/EK839E/ولادت_سید_اسد_الله_خرقانی
# ✅ 004 - /fa/event/page/FD775F/ولادت_مهدی_قلی_خان_سدید_الملک
# ✅ 005 - /fa/event/page/1K999L/ولادت_عبد_الصمد_میرزا_قاجار
# ✅ 006 - /fa/event/page/1L395K/ولادت_مسعود_میرزا_ظل_السلطان
# ✅ 007 - /fa/event/page/2E3J7J/ولادت_مظفر_الدین_شاه_قاجار
# ✅ 008 - /fa/event/page/1K361D/ولادت_امیر_مؤید_سوادکوهی
# ✅ 009 - /fa/event/page/1L02MM/ولادت_فتح_الله_اکبر
# ✅ 010 - /fa/event/page/1L395J/ولادت_کسرائیل_خانم_بانو_عظمی
# ✅ 011 - /fa/event/page/1K355M/ولادت_ضیاء_الواعظین
# ☹️ ERROR PROCESSING LINK: /fa/event/page/2E358J/ولادت_نظم_الدوله
# ☹️ ERROR PROCESSING LINK: /fa/event/page/FD34DF/ولادت_میرزا_محمد_ارباب_قمی
# ✅ 012 - /fa/event/page/2D627E/ولادت_آیت_الله_شیخ_عبد_الکریم_حائری
# ✅ 013 - /fa/event/page/1L044K/ولادت_میرزا_یحیی_امام_جمعه_خویی
# ✅ 014 - /fa/event/page/1K2M2M/ولادت_اسحاق_خان_مفخم_الدوله
# ✅ 015 - /fa/event/page/1LL47J/ولادت_اسماعیل_معتصم_الملک
# ✅ 016 - /fa/event/page/2E498E/ولادت_سلیمان_میرزا_اسکندری
# ✅ 017 - /fa/event/page/1L135H/ولادت_حاج_حسین_اقتصادی
# ✅ 018 - /fa/event/page/1L117M/ولادت_محمد_حسین_استرآبادی
# ✅ 019 - /fa/event/page/1LL61I/ولادت_مخبر_السلطنه
# ✅ 020 - /fa/event/page/2E489E/ولادت_میرزا_طاهر_تنکابنی
# ✅ 021 - /fa/event/page/1M106M/ولادت_ابراهیم_رکن_الوزاره
# ✅ 022 - /fa/event/page/1L791I/ولادت_شیخ_خزعل
# ✅ 023 - /fa/event/page/EL75LE/ولادت_حسن_مشار_الملک
# ✅ 024 - /fa/event/page/1L310H/ولادت_نصیر_خان_سردار_جنگ
# ✅ 025 - /fa/event/page/1KK65M/ولادت_سید_حسین_طباطبائی_قمی
# ✅ 026 - /fa/event/page/2D267H/ولادت_اردشیر_جی
# ✅ 027 - /fa/event/page/1L743J/ولادت_سالار_فاتح
# ✅ 028 - /fa/event/page/1L00HH/ولادت_حاج_آقا_جمال_نجفی_اصفهانی
# ✅ 029 - /fa/event/page/2D6DDL/ولادت_رضا_قلی_خان_نظام_السلطنه
# ✅ 030 - /fa/event/page/2E53EM/ولادت_محتشم_السلطنه_اسفندیاری
# ✅ 031 - /fa/event/page/2D789E/ولادت_عمید_الممالک
# ✅ 032 - /fa/event/page/2D789G/ولادت_مسعود_الملک_هزار_جریبی
# ✅ 033 - /fa/event/page/2E473J/ولادت_شیخ_اسد_الله_محلاتی
# ✅ 034 - /fa/event/page/1L073L/ولادت_میرزا_یانس_ارمنی
# ✅ 035 - /fa/event/page/2EEEDD/ولادت_شیخ_الاسلام_اصفهانی
# ✅ 036 - /fa/event/page/2E044K/ولادت_میرزا_علی_کازرونی
# ✅ 037 - /fa/event/page/2D783I/ولادت_عباسقلی_بازرگان
# ✅ 038 - /fa/event/page/2D838I/ولادت_سید_حسن_اجاق
# ✅ 039 - /fa/event/page/1L565H/ولادت_صمد_خان_ممتاز_السلطنه
# ✅ 040 - /fa/event/page/1L053F/ولادت_ابراهیم_سعید_العلما
# ✅ 041 - /fa/event/page/2D763E/ولادت_ممتاز_الملک
# ✅ 042 - /fa/event/page/2E3L7L/ولادت_حسینقلی_نواب
# ✅ 043 - /fa/event/page/EM403E/ولادت_اسد_الله_مشار_السلطنه
# ✅ 044 - /fa/event/page/EKKK8E/ولادت_میرزا_آقا_اصفهانی
# ✅ 045 - /fa/event/page/EL4E9E/ولادت_احمد_نصیر_الدوله
# ☹️ ERROR PROCESSING LINK: /fa/event/page/2D7D9J/ولادت_دکتر_سیف_الأطباء
# ✅ 046 - /fa/event/page/2E4G6G/ولادت_سدید_السلطنه_کبابی
# ✅ 047 - /fa/event/page/1M126H/ولادت_عبد_المحمد_مؤدب_السلطان
# ✅ 048 - /fa/event/page/FD69FF/ولادت_رضاقلی_هدایت
# ✅ 049 - /fa/event/page/1KK23H/ولادت_نصر_الله_خلعتبری
# ✅ 050 - /fa/event/page/2D5MDM/ولادت_ابراهیم_حکیم_الملک
# ✅ 051 - /fa/event/page/2EE97E/ولادت_حسن_وثوق_الدوله
# ✅ 052 - /fa/event/page/1J907H/ولادت_سردار_معتمد_گیلانی
# ✅ 053 - /fa/event/page/EK330E/ولادت_محمد_حسن_بدیع
# ✅ 054 - /fa/event/page/1M088I/ولادت_حسن_فلسفی
# ✅ 055 - /fa/event/page/1L3L4K/ولادت_سید_عبد_الرحیم_خلخالی
# ✅ 056 - /fa/event/page/FEE9EF/ولادت_داود_مفتاح_السلطنه
# ✅ 057 - /fa/event/page/1K618D/ولادت_وحید_الملک_شیبانی
# ✅ 058 - /fa/event/page/1LL46G/ولادت_قوام_السلطنه
# ✅ 059 - /fa/event/page/2D615H/ولادت_حسن_پیرنیا
# ✅ 060 - /fa/event/page/1KK06F/ولادت_علی_محمد_بنی_آدم
# ✅ 061 - /fa/event/page/2D718M/ولادت_سید_یعقوب_انوار_شیرازی
# ✅ 062 - /fa/event/page/EM08ME/ولادت_ناصر_الاسلام_گیلانی
# ✅ 063 - /fa/event/page/1K809F/ولادت_محمود_خان_شیبانی
# ✅ 064 - /fa/event/page/2D56DK/ولادت_حسن_مستوفی_الممالک
# ✅ 065 - /fa/event/page/2E025M/ولادت_ناظم_العلوم_بختیاری
# ✅ 066 - /fa/event/page/2E525J/ولادت_شیخ_محمد_علی_تهرانی
# ✅ 067 - /fa/event/page/1L271M/ولادت_علی_اصغر_نفیسی
# ✅ 068 - /fa/event/page/2E5E2K/ولادت_ارباب_کیخسرو
# ✅ 069 - /fa/event/page/1L134K/ولادت_سید_ولی_الله_نصر_کاشی
# ✅ 070 - /fa/event/page/1L39II/ولادت_حسینقلی_خان_معاضد_الملک
# ☹️ ERROR PROCESSING LINK: /fa/event/page/2D551D/ولادت_بصیر_الدوله_هروی
# ✅ 071 - /fa/event/page/1L00GG/ولادت_علی_اصغر_سلطان_العلماء
# ✅ 072 - /fa/event/page/2D821M/ولادت_خالو_قربان
# ✅ 073 - /fa/event/page/1K83FF/ولادت_میرزا_محسن_معتمد_التجار
# ✅ 074 - /fa/event/page/2D79DD/ولادت_دکتر_امیر_اعلم
# ✅ 075 - /fa/event/page/1K608K/ولادت_مجلل_الدوله_دولتشاهی
# ✅ 076 - /fa/event/page/1K810M/ولادت_سید_عبد_الوهاب_صالح
# ✅ 077 - /fa/event/page/1LD29D/ولادت_رضا_خان
# ✅ 078 - /fa/event/page/1L7J0J/ولادت_حبیب_الله_عین_الملک
# ✅ 079 - /fa/event/page/EL033E/ولادت_حاجی_محمد_تقی_بنکدار
# ✅ 080 - /fa/event/page/1M0M4L/ولادت_میرزا_محمد_آقازاده_خراسانی
# ✅ 081 - /fa/event/page/2E44ED/ولادت_علی_پرتو_اعظم
# ✅ 082 - /fa/event/page/2E477E/ولادت_محمد_نجات
# ✅ 083 - /fa/event/page/1J905L/ولادت_وثوق_السلطنه
# ✅ 084 - /fa/event/page/1LH37H/ولادت_ممتاز_الدوله
# ✅ 085 - /fa/event/page/1L009F/ولادت_سید_محمد_علی_داعی_الاسلام
# ✅ 086 - /fa/event/page/2D71DI/ولادت_دکتر_محمد_حسین_لقمان
# ✅ 087 - /fa/event/page/2D639D/ولادت_محمد_علی_بامداد
# ✅ 088 - /fa/event/page/2E422D/ولادت_معتمد_السلطنه
# ✅ 089 - /fa/event/page/2D798H/ولادت_احسان_الله_دوستدار
# ✅ 090 - /fa/event/page/2EEEEH/ولادت_سید_محمد_باقر_دستغیب
# ✅ 091 - /fa/event/page/EKK23E/ولادت_احتشام_حضور
# ✅ 092 - /fa/event/page/2D6D9G/ولادت_حسین_علاء
# ✅ 093 - /fa/event/page/1L11LH/ولادت_نصرت_الدوله_فیروز
# ✅ 094 - /fa/event/page/1L353L/ولادت_نادر_میرزا
# ✅ 095 - /fa/event/page/1L976L/ولادت_اکبر_صارم_الدوله
# ✅ 096 - /fa/event/page/2D633E/ولادت_علی_اکبر_داور
# ✅ 097 - /fa/event/page/2EE36I/ولادت_محمود_پولادین
# ✅ 098 - /fa/event/page/1L074I/ولادت_محمود_جم
# ✅ 099 - /fa/event/page/2E049J/ولادت_سرهنگ_اسماعیل_خان
# ✅ 100 - /fa/event/page/FD766F/ولادت_یمین_الملک
# ✅ 101 - /fa/event/page/1LG49G/ولادت_مجید_آهی
# ✅ 102 - /fa/event/page/2D844J/ولادت_رجبعلی_منصور
# ✅ 103 - /fa/event/page/EK890E/ولادت_ذکاء_الدوله_غفاری
# ✅ 104 - /fa/event/page/1K018F/ولادت_اسماعیل_میرزا_معتمد_الدوله
# ✅ 105 - /fa/event/page/2D767E/ولادت_محمد_رضا_تجدد
# ✅ 106 - /fa/event/page/1M414J/ولادت_محمد_دانش
# ✅ 107 - /fa/event/page/2EE52D/ولادت_ابو_الحسن_پورزند
# ✅ 108 - /fa/event/page/2E505M/ولادت_سعید_لقمان_الملک
# ✅ 109 - /fa/event/page/1L3K1K/ولادت_عماد_السلطنه_فاطمی
# ✅ 110 - /fa/event/page/2D6D3L/ولادت_حیدر_قلی_پسیان
# ✅ 111 - /fa/event/page/2E024I/ولادت_شموئیل_حییم
# ✅ 112 - /fa/event/page/1K128K/ولادت_ابو_القاسم_خان_احیاء_الدوله
# ✅ 113 - /fa/event/page/1L304M/ولادت_محمد_تقی_اسعد_بختیاری
# ✅ 114 - /fa/event/page/FD585F/ولادت_عباس_میرزا_فرمانفرما
# ✅ 115 - /fa/event/page/1K280I/ولادت_سید_ابو_الحسن_حائری_زاده
# ✅ 116 - /fa/event/page/1L1F4F/ولادت_محمود_صلاحی
# ✅ 117 - /fa/event/page/1L0H0H/ولادت_سید_ضیاء_الدین_طباطبایی
# ✅ 118 - /fa/event/page/2D577E/ولادت_اعتضاد_السلطنه
# ✅ 119 - /fa/event/page/2E2J9J/ولادت_سیف_الله_شهاب
# ✅ 120 - /fa/event/page/1M050H/ولادت_مرتضی_خان_یزدان_پناه
# ✅ 121 - /fa/event/page/1LL5LF/ولادت_محمد_تقی_خان_پسیان
# ✅ 122 - /fa/event/page/2D76DM/ولادت_ابو_القاسم_نجم_الملک
# ✅ 123 - /fa/event/page/1K566H/ولادت_سید_حسین_عدالت
# ✅ 124 - /fa/event/page/2D566L/ولادت_سردار_همایون
# ✅ 125 - /fa/event/page/2D73DM/ولادت_میرزا_عباس_خلیلی
# ✅ 126 - /fa/event/page/EL799E/ولادت_عیسی_صدیق
# ✅ 127 - /fa/event/page/1LL04G/ولادت_میرزاده_عشقی
# ✅ 128 - /fa/event/page/1L12II/ولادت_احمد_صلاحی
# ✅ 129 - /fa/event/page/1L0L9H/ولادت_مسعود_کیهان
# ✅ 130 - /fa/event/page/2E039H/ولادت_سردار_فاخر_حکمت
# ✅ 131 - /fa/event/page/1LKKLK/ولادت_علی_اصغر_حکمت
# ✅ 132 - /fa/event/page/2D774J/ولادت_سید_محمد_رضا_خراسانی
# ✅ 133 - /fa/event/page/2E02KK/ولادت_سالار_نظام
# ✅ 134 - /fa/event/page/EL29LE/ولادت_امیر_حسین_خان_بختیاری
# ✅ 135 - /fa/event/page/1L034K/ولادت_کاظم_سیاح
# ✅ 136 - /fa/event/page/1M125K/ولادت_سید_محمد_تقی_گلستان
# ✅ 137 - /fa/event/page/2EEE5D/ولادت_علی_اکبر_درخشانی
# ✅ 138 - /fa/event/page/1L010F/ولادت_احمد_متین_دفتری
# ✅ 139 - /fa/event/page/2EE05L/ولادت_فطن_السلطنه
# ✅ 140 - /fa/event/page/1K122G/ولادت_غلامرضا_رشید_یاسمی
# ✅ 141 - /fa/event/page/1LD39D/ولادت_احمد_شاه_قاجار
# ✅ 142 - /fa/event/page/2EEL3L/ولادت_حسن_مقدم
# ✅ 143 - /fa/event/page/2D777I/ولادت_ید_الله_عضدی
# ✅ 144 - /fa/event/page/1L6F1F/ولادت_ابو_القاسم_کحال_زاده
# ☹️ ERROR PROCESSING LINK: /fa/event/page/1KKK8G/ولادت_هدایت_الله_داوری
# ✅ 145 - /fa/event/page/1MGMMG/ولادت_عباسخان_امیر_مخصوص
# ✅ 146 - /fa/event/page/2D6D8K/ولادت_لطفعلی_صورتگر
# ✅ 147 - /fa/event/page/2E07EI/ولادت_زین_العابدین_خان_مستوفی
# ✅ 148 - /fa/event/page/2D715J/ولادت_صولت_الدوله_قشقایی
# ✅ 149 - /fa/event/page/2E085G/ولادت_عضد_السلطان_قاجار
# ✅ 150 - /fa/event/page/1J015M/ولادت_علیرضا_پهلوی
# ✅ 151 - /fa/event/page/2DK31K/ولادت_سیمین_بهبهانی
# ✅ 152 - /fa/event/page/1L06LI/ولادت_محمد_مصدق
# ✅ 153 - /fa/event/page/1M084I/ولادت_قاسم_صور_اسرافیل

# %%
process_pages('JUDICIAL', range(1, 5 + 1))
# Out:
# ✅ 001 - /fa/event/page/1K132L/احضار_و_محاکمه_معین_الرسائل
# ✅ 002 - /fa/event/page/1K132K/احضار_مسئولان_صندوق_مالیه
# ✅ 003 - /fa/event/page/1K132M/احضار_اعتضاد_همایون
# ✅ 004 - /fa/event/page/1K239H/دستور_رسیدگی_به_اتباع_لهستانی_زندانی_در_کنسولگری_روسیه
# ✅ 005 - /fa/event/page/1K23KL/رسیدگی_به_اتهامات_کامیل_مولیتور
# ✅ 006 - /fa/event/page/EK238E/تبرئه_سید_ابو_الحسن_نائینی
# ✅ 007 - /fa/event/page/1K238I/تبرئه_معین_الرسائل
# ✅ 008 - /fa/event/page/1K29KK/تازیانه_زدن_و_تبعید_پزشک_کلیمی_به_جرم_توهین_به_اسلام
# ✅ 009 - /fa/event/page/1K352H/رسیدگی_به_عملکرد_میرزا_یوسف_خان_قائم_مقام
# ✅ 010 - /fa/event/page/1K5K4J/رسیدگی_به_عملکرد_میرزا_یوسف_خان_قائم_مقام
# ✅ 011 - /fa/event/page/1K5M1M/اعدام_سالار_محتشم
# ✅ 012 - /fa/event/page/1K585K/اعدام_اشرار_زنجان
# ✅ 013 - /fa/event/page/1KJ0JJ/محاکمه_نیروهای_خالو_قربان
# ✅ 014 - /fa/event/page/2E3K5K/عفو_عبد_القدیر_آزاد_و_زبردست_خان
# ✅ 015 - /fa/event/page/1K633H/توقیف_روزنامه_اقتصاد_ایران
# ✅ 016 - /fa/event/page/1K644G/دستور_اعدام_قاتلان_نظامیان
# ✅ 017 - /fa/event/page/1KK43J/احضار_سردار_صولت
# ✅ 018 - /fa/event/page/1KKJ4J/اثبات_اختلاس_کامیل_مولیتور
# ✅ 019 - /fa/event/page/1KKK1L/دستگیری_تعدادی_از_کلیمی_ها
# ✅ 020 - /fa/event/page/1KK80F/محکومیت_ارفع_الممالک
# ✅ 021 - /fa/event/page/1KK8JJ/منع_بین_المللی_استعمال_تریاک
# ✅ 022 - /fa/event/page/1K808M/رسیدگی_به_اختلاس_های_کامیل_مولیتور
# ✅ 023 - /fa/event/page/1K814M/آزادی_مدیر_روزنامه_حیات
# ✅ 024 - /fa/event/page/1K841D/اعدام_شاهزاده_اسماعیل
# ✅ 025 - /fa/event/page/1K838I/اعدام_سید_جلال_چمنی_و_یارانش
# ✅ 026 - /fa/event/page/1K985G/دستگیری_گروهی_از_آزادی_خواهان_مخالف_قوام_السلطنه
# ✅ 027 - /fa/event/page/1K991J/دستگیری_شیخ_حسن_لنکرانی
# ✅ 028 - /fa/event/page/1K991I/دستگیری_میرزا_همایون_خان
# ✅ 029 - /fa/event/page/1K991L/دستگیری_محبعلی_خان
# ✅ 030 - /fa/event/page/1K991K/دستگیری_معتصم_السلطنه

# %%
process_pages('CULTURAL', range(1, 10 + 1))
# Out:
# ✅ 001 - /fa/event/page/2ED24D/فعالیت_مبلغان_کاتولیک_فرانسوی_در_غرب_آذربایجان
# ✅ 002 - /fa/event/page/2E42JJ/تأسیس_دبستان_دخترانه_آمریکایی_در_ارومیه
# ✅ 003 - /fa/event/page/2E426E/تأسیس_مدرسه_شبانه_روزی_آمریکایی_در_آذربایجان
# ✅ 004 - /fa/event/page/FE0F4F/تأسیس_مدرسه_سن_لویی_در_تهران
# ✅ 005 - /fa/event/page/2E428G/گسترش_دامنه_فعالیت_میسیون_آمریکایی_در_ایران
# ✅ 006 - /fa/event/page/2E428J/تأسیس_دبستان_ارامنه_توسط_میسیون_آمریکایی_در_ایران
# ✅ 007 - /fa/event/page/2D3JDJ/انتشار_روزنامه_الاهرام
# ✅ 008 - /fa/event/page/2E426M/تأسیس_مدرسه_شبانه_روزی_دخترانه_آمریکایی_در_آذربایجان
# ✅ 009 - /fa/event/page/1LLJ1J/تحصیل_مخبر_السلطنه_در_آلمان
# ✅ 010 - /fa/event/page/1K348J/تأسیس_آلیانس_فرانسه_کانون_ملی_برای_ترویج_زبان_فرانسه
# ✅ 011 - /fa/event/page/2E5E2M/تحصیل_ارباب_کیخسرو_در_تهران
# ✅ 012 - /fa/event/page/2E375L/انتشار_روزنامه_آزاد
# ✅ 013 - /fa/event/page/1KK66D/تحصیل_سید_حسین_طباطبائی_قمی_نزد_میرزای_شیرازی
# ✅ 014 - /fa/event/page/1LL61K/تدریس_زبان_آلمانی_توسط_مخبر_السلطنه_در_دار_الفنون
# ✅ 015 - /fa/event/page/FE5E3F/آموزگاری_ارباب_کیخسرو_در_دبستان_کرمان
# ✅ 016 - /fa/event/page/1K348K/تأسیس_کمیته_آلیانس_در_تهران_و_شیراز
# ✅ 017 - /fa/event/page/2D591G/تحصیل_ابراهیم_حکیم_الملک_در_مدرسه_دار_الفنون_تهران
# ✅ 018 - /fa/event/page/2D591D/تحصیل_ابراهیم_حکیم_الملک_در_دار_الفنون_مظفری_تبریز
# ✅ 019 - /fa/event/page/2DI91I/تحصیل_ابراهیم_حکیم_الملک_در_دانشگاه_پاریس
# ✅ 020 - /fa/event/page/1KK66F/تحصیل_سید_حسین_طباطبائی_قمی_نزد_میرزا_حبیب_الله_رشتی
# ✅ 021 - /fa/event/page/1KKJJJ/اجازه_اجتهاد_سید_حسین_طباطبائی_قمی_از_میرزای_شیرازی
# ✅ 022 - /fa/event/page/1KK66H/تحصیل_سید_حسین_طباطبائی_قمی_نزد_آخوند_خراسانی
# ✅ 023 - /fa/event/page/1KK66G/تحصیل_سید_حسین_طباطبائی_قمی_نزد_ملاعلی_نهاوندی
# ✅ 024 - /fa/event/page/1KK66I/تحصیل_سید_حسین_طباطبائی_قمی_نزد_سید_محمد_کاظم_یزدی
# ✅ 025 - /fa/event/page/2D628H/تحصیل_آیت_الله_شیخ_عبد_الکریم_حائری_نزد_آخوند_خراسانی
# ✅ 026 - /fa/event/page/1L0I3I/تحصیل_ابراهیم_سعید_العلما_نزد_میرزا_ابو_الحسن_جلوه
# ✅ 027 - /fa/event/page/1L053H/تحصیل_ابراهیم_سعید_العلما_نزد_شیخ_علی_مدرس_نوری
# ✅ 028 - /fa/event/page/1L054K/تحصیل_ابراهیم_سعید_العلما_نزد_شیخ_عبد_النبی_نوری
# ✅ 029 - /fa/event/page/1L053J/تحصیل_ابراهیم_سعید_العلما_نزد_میرزا_حسن_آشتیانی
# ✅ 030 - /fa/event/page/2D7D9L/تدریس_دکتر_سیف_الأطباء_در_دار_الفنون_تبریز
# ✅ 031 - /fa/event/page/2E429J/تحصیل_مسلمانان_در_مدرسه_آمریکایی_در_تهران
# ✅ 032 - /fa/event/page/1L054L/تأسیس_مدرسه_قدسیه
# ✅ 033 - /fa/event/page/2D267L/تدریس_اردشیر_جی_در_مدرسه_علوم_سیاسی
# ✅ 034 - /fa/event/page/2D71DJ/تحصیل_دکتر_محمد_حسین_لقمان_در_دانشکده_پزشکی_پاریس
# ✅ 035 - /fa/event/page/1K125H/تأسیس_مدرسه_علوم_سیاسی
# ✅ 036 - /fa/event/page/2D61DI/تحصیل_حسین_علاء_در_دانشکده_حقوق_دانشگاه_لندن
# ✅ 037 - /fa/event/page/2D6EDE/تحصیل_حسین_علاء_در_لندن
# ✅ 038 - /fa/event/page/1KM05M/تأسیس_مدرسه_آمریکایی_در_رشت
# ✅ 039 - /fa/event/page/1LD1DD/انتشار_مجله_الاسلام
# ✅ 040 - /fa/event/page/2D79DG/دریافت_نشان_درجه_اول_علمی_توسط_دکتر_امیر_اعلم_از_دولت_فرانسه
# ✅ 041 - /fa/event/page/2E526E/نقش_شیخ_محمد_علی_تهرانی_در_تأسیس_انجمن_علمی
# ✅ 042 - /fa/event/page/EL0E0E/توقف_انتشار_مجله_الاسلام
# ✅ 043 - /fa/event/page/2D79DJ/تحصیل_طب_نظامی_توسط_دکتر_امیر_اعلم_در_پاریس
# ✅ 044 - /fa/event/page/1LL06I/تاسیس_اولین_سینما_در_ایران
# ✅ 045 - /fa/event/page/2D7MDM/تدریس_دکتر_امیر_اعلم_در_مدرسه_طب
# ✅ 046 - /fa/event/page/2D841G/تحصیل_سید_محمد_تقی_فخر_در_نجف
# ✅ 047 - /fa/event/page/1K565K/انتشار_روزنامه_شالوم
# ✅ 048 - /fa/event/page/1L009K/مباحثه_سید_محمد_علی_داعی_الاسلام_با_مبلغان_مسیحی
# ✅ 049 - /fa/event/page/2E506E/تحصیل_سعید_لقمان_الملک_در_دانشکده_طب_فرانسه
# ✅ 050 - /fa/event/page/1L3L4M/انتشار_روزنامه_مساوات
# ✅ 051 - /fa/event/page/1LL5LG/تحصیل_محمد_تقی_خان_پسیان_در_مدرسه__نظام_تهران
# ✅ 052 - /fa/event/page/1L040I/انتشار_روزنامه_ندای_اسلام
# ✅ 053 - /fa/event/page/2E294K/تشکیل_انجمن_فرهنگ_توسط_محمد_علی_فرزین
# ✅ 054 - /fa/event/page/FE477F/انتشار_روزنامه_حقوق
# ✅ 055 - /fa/event/page/1L009J/انتشار_مجله_دعوت_الاسلام
# ✅ 056 - /fa/event/page/2D761D/تحصیل_ابو_القاسم_نجم_الملک_در_مدرسه_علوم_سیاسی
# ✅ 057 - /fa/event/page/1LL0JJ/تاسیس_سینما_توسط_روسی_خان
# ✅ 058 - /fa/event/page/1M0M4M/اجازه_اجتهاد_میرزا_محمد_آقازاده_خراسانی
# ✅ 059 - /fa/event/page/1K623L/اعطای_نشان_طلای_علمی_درجه_اول_به_اقتدار_الملک
# ✅ 060 - /fa/event/page/2EE83M/تحصیل_حسن_مقدم_در_سوئیس
# ✅ 061 - /fa/event/page/1MDM5D/تشکیل_حوزه_درسی_در_مسجد_گوهرشاد_توسط_میرزا_محمد_آقازاده_خراسانی
# ✅ 062 - /fa/event/page/FE44EF/اخذ_مدرک_دکتری_توسط_علی_پرتو_اعظم
# ✅ 063 - /fa/event/page/EK620E/تدریس_زبان_انگلیسی_توسط_وحید_الملک_شیبانی
# ✅ 064 - /fa/event/page/2D6GGG/فارغ_التحصیل_شدن_علی_اکبر_داور
# ✅ 065 - /fa/event/page/2D634I/عضویت_علی_اکبر_داور_در_هیأت_تحریریه_روزنامه_شرق
# ✅ 066 - /fa/event/page/2EH56H/بازگشت_سید_فاضل_کاشانی_به_ایران
# ✅ 067 - /fa/event/page/1K992J/بازگشایی_مجدد_مدرسه_سپهسالار
# ✅ 068 - /fa/event/page/2E4I6I/تحصیل_سید_فاضل_کاشانی_در_نجف
# ✅ 069 - /fa/event/page/1L040J/انتشار_روزنامه_شرق
# ✅ 070 - /fa/event/page/2DK1DK/فارغ_التحصیل_شدن_دکتر_محمد_حسین_لقمان
# ✅ 071 - /fa/event/page/1L063K/انتشار_نشریه_استقلال_ایران
# ✅ 072 - /fa/event/page/2DL2LL/تدریس_عیسی_صدیق_در_دانشگاه_کمبریج
# ✅ 073 - /fa/event/page/2D828K/تحصیل_عیسی_صدیق_در_انگلیس
# ✅ 074 - /fa/event/page/2E049L/تحصیل_سرهنگ_اسماعیل_خان_در_روسیه
# ✅ 075 - /fa/event/page/2D828I/تحصیل_عیسی_صدیق_در_فرانسه
# ✅ 076 - /fa/event/page/2E269K/تحصیل_سیف_الله_شهاب_در_پاریس
# ✅ 077 - /fa/event/page/FDF47F/انتشار_روزنامه_رسمی
# ✅ 078 - /fa/event/page/1K992K/تولیت_سید_حسن_مدرس_بر_مدرسه_سپهسالار
# ✅ 079 - /fa/event/page/FD761F/تدریس_ابو_القاسم_نجم_الملک_در_مدرسه_علوم_سیاسی
# ✅ 080 - /fa/event/page/1KK66K/مهاجرت_سید_حسین_طباطبائی_قمی_به_مشهد
# ✅ 081 - /fa/event/page/2D777J/تحصیل_ید_الله_عضدی_در_ترکیه
# ✅ 082 - /fa/event/page/1LL06K/تاسیس_سینما_توسط_اردشیر_خان
# ✅ 083 - /fa/event/page/2E508G/تألیف_پایان_نامه_توسط_سعید_لقمان_الملک
# ✅ 084 - /fa/event/page/1LL04I/نمایشنامه_نویسی_میرزاده_عشقی
# ✅ 085 - /fa/event/page/2E42MM/تشکیل_دوره_تحصیلی_دوازده_ساله_در_ایران
# ✅ 086 - /fa/event/page/2D62LL/اقامت_آیت_الله_شیخ_عبد_الکریم_حائری_در_اراک
# ✅ 087 - /fa/event/page/2D628M/تأسیس_حوزه_علمیه_اراک_توسط_آیت_الله_شیخ_عبد_الکریم_حائری
# ✅ 088 - /fa/event/page/2D777G/چاپ_کتاب_تاریخ_انقلاب_ایران
# ✅ 089 - /fa/event/page/2DJ28J/سفر_آیت_الله_شیخ_عبد_الکریم_حائری_به_ایران
# ✅ 090 - /fa/event/page/2D639K/انتشار_روزنامه_بامداد_روشن
# ✅ 091 - /fa/event/page/2D532K/تصویب_امتیاز_مجله_ستاره_شرق
# ✅ 092 - /fa/event/page/2D711G/اهدای_600_جلد_کتاب_به_مدرسه_طبی_توسط_دکتر_محمد_حسین_لقمان
# ✅ 093 - /fa/event/page/1M117G/تاسیس_اولین_مدرسه_دخترانه_در_اصفهان
# ✅ 094 - /fa/event/page/1M125M/انتشار_روزنامه_گلستان_توسط_سید_محمد_تقی_گلستان
# ✅ 095 - /fa/event/page/EM384E/تأسیس_مدرسه_اقبال_در_ماکو
# ✅ 096 - /fa/event/page/2D829E/تدریس_عیسی_صدیق_در_مدرسه_دار_الفنون
# ✅ 097 - /fa/event/page/1L349F/تحصیل_مجید_آهی_در_روسیه
# ✅ 098 - /fa/event/page/1L799H/فارغ_التحصیل_شدن_عیسی_صدیق
# ✅ 099 - /fa/event/page/2D828M/تلاش_عیسی_صدیق_برای_معرفی_زبان_فارسی_در_فرانسه
# ✅ 100 - /fa/event/page/2E5J5J/انتشار_روزنامه_گلشن
# ✅ 101 - /fa/event/page/1M0H7H/ریاست_ابو_الحسن_فروغی_بر_مدرسه_دار_المعلمین
# ✅ 102 - /fa/event/page/1M047G/تاسیس_مدرسه_دار_المعلمین
# ✅ 103 - /fa/event/page/1M06ML/تاسیس_مدرسه_شرافت_ایرانیان_در_بغداد
# ✅ 104 - /fa/event/page/1KKK8F/انتشار_روزنامه_حیات
# ☹️ ERROR PROCESSING LINK: /fa/event/page/1L11LD/تدریس_محمد_حسین_استرآبادی_در_مدرسه_عالی_حقوق
# ✅ 105 - /fa/event/page/2D214G/تأسیس_مدرسه_عالی_حقوق_در_تهران
# ✅ 106 - /fa/event/page/1M117J/انتشار_روزنامه_زبان_زنان
# ✅ 107 - /fa/event/page/1M407I/انتخاب_دکتر_منار_فرانسوی_به_ریاست_انستیتو_پاستور
# ✅ 108 - /fa/event/page/1K12II/تأسیس_مدرسه_حقوق
# ✅ 109 - /fa/event/page/1M407L/دوره_ریاست_دکتر_منار_فرانسوی_بر_انستیتو_پاستور
# ✅ 110 - /fa/event/page/2E2E7H/تحصیل_حسن_وثوق_الدوله_در_رشته_فلسفه_در_اروپا
# ✅ 111 - /fa/event/page/1L1G5G/انتشار_روزنامه_اقتصاد_ایران
# ✅ 112 - /fa/event/page/1M407J/تاسیس_انستیتو_پاستور
# ✅ 113 - /fa/event/page/1M414L/توقف_انتشار_مجله_دانش
# ✅ 114 - /fa/event/page/2D294L/انتشار_روزنامه_عصر_آزادی
# ✅ 115 - /fa/event/page/1L372M/انتشار_مجله_عالم_نسوان
# ✅ 116 - /fa/event/page/1L939J/انتشار_روزنامه_نوروز
# ✅ 117 - /fa/event/page/1LL75D/انتشار_روزنامه_مهر_منیر
# ✅ 118 - /fa/event/page/2D731I/انتشار_روزنامه_اقدام
# ✅ 119 - /fa/event/page/FD635F/تحصیل_علی_اکبر_داور_در_سوئیس
# ✅ 120 - /fa/event/page/1K355L/انتشار_روزنامه_ایران
# ✅ 121 - /fa/event/page/1L757H/تالیف_کتاب_تاریخ_جنبش_صهیونیست
# ✅ 122 - /fa/event/page/1J539D/انتشار_نشریه_جهان_زنان
# ✅ 123 - /fa/event/page/1L79FF/انتشار_روزنامه_گل_زرد_توسط_یحیی_سمیعیان
# ✅ 124 - /fa/event/page/1L40LK/تدریس_منصور_السلطنه_در_مدرسه_علوم_سیاسی
# ✅ 125 - /fa/event/page/1L333K/ارائه_طرح_آموزش_اجباری_زنان
# ✅ 126 - /fa/event/page/1L6F7F/شعر_خوانی_حسین_دانش_در_جشن_نوروز
# ✅ 127 - /fa/event/page/1L627G/شعر_خوانی_ابو_القاسم_لاهوتی_در_جشن_نوروز
# ✅ 128 - /fa/event/page/1L7M0M/انتشار_نشریه_نوروز
# ✅ 129 - /fa/event/page/1LL61F/آغاز_به_کار_کتابخانه_ملی_در_اصفهان
# ✅ 130 - /fa/event/page/1LL6LK/صدور_مجوز_انتشار_روزنامه_ناهید
# ☹️ ERROR PROCESSING LINK: /fa/event/page/1LL71M/انتشار_نشریات_در_مشهد
# ✅ 131 - /fa/event/page/1L96LL/ثبت_نام_مسابقات_اسب_دوانی_در_اصفهان
# ✅ 132 - /fa/event/page/1L969D/انتشار_روزنامه_ناهید
# ✅ 133 - /fa/event/page/FEE83F/انتشار_مجله_پارس_در_استانبول
# ✅ 134 - /fa/event/page/2EE8GG/مدیریت_حسن_مقدم_بر_بخش_فرانسوی_مجله_پارس
# ✅ 135 - /fa/event/page/2EE83H/مدیریت_ابو_القاسم_لاهوتی_بر_بخش_فارسی_مجله_پارس
# ✅ 136 - /fa/event/page/FEE90F/انتشار_روزنامه_خراسان
# ✅ 137 - /fa/event/page/FEF85F/انتشار_روزنامه_قرن_بیستم
# ✅ 138 - /fa/event/page/2E424K/برگزاری_جشن_عید_فطر_در_سفارت_افغانستان_در_تهران
# ✅ 139 - /fa/event/page/2E425J/برپایی_مراسم_فارغ_التحصیلی_در_مدرسه_آمریکایی_در_تهران
# ✅ 140 - /fa/event/page/2E56ED/انتشار_مجدد_نشریه_حلاج
# ✅ 141 - /fa/event/page/2EE83K/متوقف_شدن_انتشار_مجله_پارس
# ✅ 142 - /fa/event/page/2E565G/انتشار_روزنامه_گلشن
# ✅ 143 - /fa/event/page/2D777H/انتشار_کتاب_تاریخ_انقلاب_ایران
# ✅ 144 - /fa/event/page/1KK10I/انتشار_نشریه_ندای_گیلان
# ✅ 145 - /fa/event/page/2D629E/تأسیس_حوزه_علمیه_قم_توسط_آیت_الله_شیخ_عبد_الکریم_حائری
# ✅ 146 - /fa/event/page/2D7LLL/انتشار_روزنامه_سیاست
# ✅ 147 - /fa/event/page/1M118J/انتشار_مجله_زبان_زنان
# ✅ 148 - /fa/event/page/1M415G/انتشار_روزنامه_استقامت
# ✅ 149 - /fa/event/page/1LL0HH/انتشار_نشریه_قرن_بیستم
# ✅ 150 - /fa/event/page/2D629D/اقامت_ایت_الله_شیخ_عبد_الکریم_حائری_در_قم
# ✅ 151 - /fa/event/page/1I98II/انتشار_ماهنامه_سپیده_دم
# ✅ 152 - /fa/event/page/1JD25D/افتتاح_حوزه_علمیه_در_خیابان_چراغ_برق
# ✅ 153 - /fa/event/page/1J039I/انتقاد_نشریه_گلشن_به_نزاع_بین_روزنامه_ها
# ✅ 154 - /fa/event/page/1J041L/پیشنهاد_اعزام_دانشجو_به_اروپا_و_آمریکا
# ✅ 155 - /fa/event/page/1J047M/محول_شدن_نظارت_بر_نظامنامه_مدارس_جدید_بیرجند_به_علمای_آنجا
# ✅ 156 - /fa/event/page/1J048G/معرفی_کتاب_رویدادهای_اخیر_ایران
# ✅ 157 - /fa/event/page/EJ0JJE/دعوت_به_شرکت_در_سخنرانی_رضا_زاده_شفق
# ✅ 158 - /fa/event/page/1J0J9H/افتتاح_شعبه_دواسازی_مدرسه_طبی
# ✅ 159 - /fa/event/page/1J177D/معرفی_کتاب_ترجمه_تاریخ_انقلاب_ایران
# ✅ 160 - /fa/event/page/1J179G/سخنرانی_معاون_التولیه_در_جمع_بازرگانان
# ✅ 161 - /fa/event/page/1J179D/سخنرانی_میرزا_ابو_طالب_اسلامی_در_جمع_بازرگانان
# ✅ 162 - /fa/event/page/EJE79E/سخنرانی_سید_محمد_اسلامبولچی_در_جمع_بازرگانان
# ✅ 163 - /fa/event/page/1J179F/سخنرانی_عباسقلی_بازرگان_در_جمع_بازرگانان
# ✅ 164 - /fa/event/page/1J194L/مقاله_دکتر_امیر_اعلم_درباره_تأسیس_جمعیت_شیر_و_خورشید_سرخ
# ✅ 165 - /fa/event/page/1J213L/معرفی_کتاب_لایحه_سیاسی_اسلامی_در_روزنامه_اقدام
# ✅ 166 - /fa/event/page/1J249K/افتتاح_مدرسه_انگلیسی_در_لرستان
# ✅ 167 - /fa/event/page/1J397J/درخواست_صدور_امتیاز_نشریه_اندرز
# ✅ 168 - /fa/event/page/1J495L/انتشار_نشریه_هحییم
# ✅ 169 - /fa/event/page/1J538J/انتشار_مجدد_روزنامه_زبان_زنان
# ✅ 170 - /fa/event/page/1J553H/انتشار_روزنامه_خنده
# ✅ 171 - /fa/event/page/1J721D/معرفی_کتاب_علل_بدبختی_ما_و_علاج_آن_در_روزنامه_اتحاد
# ✅ 172 - /fa/event/page/1J727D/سرمقاله_روزنامه_شفق_سرخ_علیه_شوروی
# ✅ 173 - /fa/event/page/1K124M/دریافت_مدرک_لیسانس_از_مدرسه_حقوق
# ✅ 174 - /fa/event/page/1K5K1H/اعلام_سخنرانی_غلامرضا_رشید_یاسمی
# ✅ 175 - /fa/event/page/1K5M2M/خبر_شومیاتسکی_از_افتتاح_مدرسه_عملی_روس_و_ایران
# ✅ 176 - /fa/event/page/1M004K/انتشار_نشریه_افق_روشن
# ✅ 177 - /fa/event/page/1M384D/تحصیل_زنان_ماکویی_در_روسیه
# ✅ 178 - /fa/event/page/2D5G9G/انتشار_روزنامه_قیام
# ✅ 179 - /fa/event/page/2E5E3H/تأسیس_انجمن_آثار_ملی
# ✅ 180 - /fa/event/page/2D585E/مدیریت_سید_کاظم_سرکشیک_زاده_بر_روزنامه_اتحاد
# ✅ 181 - /fa/event/page/2D248E/انتشار_روزنامه_شهاب
# ✅ 182 - /fa/event/page/1M406I/ریاست_دکتر_منار_فرانسوی_بر_انستیتو_پاستور
# ✅ 183 - /fa/event/page/EK632E/تأسیس_قرائت_خانه_حریّت
# ✅ 184 - /fa/event/page/1L00LJ/انتشار_روزنامه_پژوهش
# ✅ 185 - /fa/event/page/1K9K8H/تحصیل_91_نفر_در_مدارس_عالی
# ✅ 186 - /fa/event/page/2D532H/انتشار_روزنامه_ستاره_شرق
# ✅ 187 - /fa/event/page/1L003F/صدور_امتیاز_نشریه_گفتار_راست
# ✅ 188 - /fa/event/page/1L00JJ/کمبود_معلم_در_مدارس_مازندران
# ✅ 189 - /fa/event/page/1L57JJ/تشکیل_مجمع_آشیان_عشق
# ✅ 190 - /fa/event/page/1L605F/انتشار_نشریه_آسیای_مرکزی
# ✅ 191 - /fa/event/page/1L9LLF/اطلاعیه_خبرگزاری_رویتر_در_ایران
# ✅ 192 - /fa/event/page/1L9L9I/مقاله_زین_العابدین_رهنما_در_هفتمین_سال_انتشار_روزنامه_ایران
# ✅ 193 - /fa/event/page/1M0M0L/تاسیس_مدرسه_تلگراف_بی_سیم_در_تاشکند
# ✅ 194 - /fa/event/page/1M0M0I/اعطای_نشان_علمی_به_سید_باقر_خان
# ✅ 195 - /fa/event/page/1M104K/جشن_فارغ_التحصیلی_در_دار_الفنون
# ✅ 196 - /fa/event/page/1M135D/آزمون_مترجمی_برای_کار_با_میلسپو
# ✅ 197 - /fa/event/page/1M140M/انتشار_روزنامه_دستور_اخوت
# ✅ 198 - /fa/event/page/1M140L/انتشار_روزنامه_بیداری
# ✅ 199 - /fa/event/page/1M386H/افتتاح_مدرسه_روسی_غازیان
# ✅ 200 - /fa/event/page/1M3M7M/توزیع_کتاب_بین_دانش_آموزان_فقیر
# ✅ 201 - /fa/event/page/2D217I/تاسیس_آموزشگاه_علوم_مهندسی_در_گردان_مستقل_مهندسی_ارتش
# ✅ 202 - /fa/event/page/2D226D/انتشار_روزنامه_کوشش
# ✅ 203 - /fa/event/page/2D24DM/افتتاح_مدرسه_اداره_راه
# ☹️ ERROR PROCESSING LINK: /fa/event/page/2D2H1H/افتتاح_مدرسه_روسی_قزوین
# ✅ 204 - /fa/event/page/2D247J/انتشار_مجدد_روزنامه_رسمی
# ✅ 205 - /fa/event/page/2D26DD/سخنرانی_اردشیر_جی_درباره_ابو_القاسم_فردوسی
# ✅ 206 - /fa/event/page/2D259L/افتتاح_قرائت_خانه_فردوسی
# ✅ 207 - /fa/event/page/2D25MM/سخنرانی_خدا_رحم_بهمن_در_مراسم_افتتاح_قرائت_خانه_فردوسی
# ✅ 208 - /fa/event/page/2D26DE/شعر_خوانی_میرزاده_عشقی_در_مراسم_افتتاح_قرائت_خانه_فردوسی
# ✅ 209 - /fa/event/page/2DI31I/گزارش_روزنامه_اتحاد_از_وضعیت_فقرا_در_مراغه
# ✅ 210 - /fa/event/page/2D537M/تأسیس_مدرسه_پهلوی_در_سلماس
# ✅ 211 - /fa/event/page/FD554F/تحصیل_100_دانشجوی_ایرانی_در_روسیه
# ✅ 212 - /fa/event/page/2DI6II/انتشار_روزنامه_مرد_آزاد
# ✅ 213 - /fa/event/page/FD575F/پایه_گذاری_جمعیت_نسوان_وطن_خواه_ایران
# ✅ 214 - /fa/event/page/1M141D/واگذاری_مسئولیت_اداره_روزنامه_دستور_اخوت_به_سید_محمد_باقر_دبیری
# ✅ 215 - /fa/event/page/1K642G/انتشار_روزنامه_لواء_بین_النهرین
# ✅ 216 - /fa/event/page/2D575L/انتشار_مجله_جمعیت_نسوان_وطن_خواه
# ✅ 217 - /fa/event/page/1K3IKI/انتشار_مجدد_روزنامه_ایران
# ✅ 218 - /fa/event/page/2DK6KK/انتشار_روزنامه_تجدد
# ✅ 219 - /fa/event/page/1M4D8D/ریاست_ابو_القاسم_بهرامی_بر_انستیتو_پاستور
# ✅ 220 - /fa/event/page/2D829K/تدریس_عیسی_صدیق_در_دار_المعلمین_و_مدرسه_حقوق
# ✅ 221 - /fa/event/page/1K992L/تولیت_مجدد_سید_حسن_مدرس_بر_مدرسه_سپهسالار
# ✅ 222 - /fa/event/page/1K125J/الحاق_مدرسه_علوم_سیاسی_و_مدرسه_حقوق_به_وزارت_معارف_و_اوقاف
# ✅ 223 - /fa/event/page/EL009E/انتشار_روزنامه_استقلال_وطن
# ✅ 224 - /fa/event/page/2EE90K/توقف_انتشار_روزنامه_خراسان
# ✅ 225 - /fa/event/page/1L351L/تدریس_مجید_آهی_در_مدرسه_تجارت
# ✅ 226 - /fa/event/page/2D6DLL/تحصیل_لطفعلی_صورتگر_در_انگلیس
# ✅ 227 - /fa/event/page/1K125K/انتصاب_علی_اکبر_دهخدا_به_ریاست_مدرسه_حقوق_و_علوم_سیاسی
# ✅ 228 - /fa/event/page/2D731L/کسب_جایزه_دوم_شعر_عرب_توسط_میرزا_عباس_خلیلی
# ✅ 229 - /fa/event/page/2E430E/تأسیس_دبیرستان_البرز
# ✅ 230 - /fa/event/page/1M047I/تبدیل_مدرسه_دار_المعلمین_به_دار_المعلمین_عالی
# ✅ 231 - /fa/event/page/1K993K/تولیت_علی_اصغر_حکمت_بر_مدرسه_سپهسالار
# ✅ 232 - /fa/event/page/2D63EE/تحصیل_علیرضا_پهلوی_در_لوزان
# ✅ 233 - /fa/event/page/2D831D/تهیه_طرح_تأسیس_دانشگاه_تهران_توسط_عیسی_صدیق
# ✅ 234 - /fa/event/page/2D83EE/مأموریت_اجرای_طرح_تأسیس_دانشگاه_تهران_توسط_عیسی_صدیق
# ✅ 235 - /fa/event/page/2D83DM/اخذ_دکترای_فلسفه_توسط_عیسی_صدیق
# ✅ 236 - /fa/event/page/2E2H5H/آغاز_ثبت_نام_مدرسه_نظام_تهران
# ✅ 237 - /fa/event/page/FD831F/ریاست_عیسی_صدیق_بر_دار_المعلمین
# ✅ 238 - /fa/event/page/2D6D8M/تحصیل_لطفعلی_صورتگر_در_انگلیس
# ✅ 239 - /fa/event/page/2D832M/تأسیس_دانشگاه_تبریز
# ✅ 240 - /fa/event/page/1LLD7D/فعالیت_8_سینما_در_تهران
# ✅ 241 - /fa/event/page/1K998J/رونق_گرفتن_مدرسه_سپهسالار
# ✅ 242 - /fa/event/page/1M414K/انتشار_دیوان_شعر_محمد_دانش_با_عنوان_راز_دانش
# ✅ 243 - /fa/event/page/1L623D/انتشار_خاطرات_ابو_القاسم_کحال_زاده
# ✅ 244 - /fa/event/page/1M04KK/تغییر_نام_دانشسرای_عالی_به_دانشگاه_تربیت_معلم
# ✅ 245 - /fa/event/page/1M047J/تغییر_نام_مدرسه_دار_المعلمین_به_دانشسرای_عالی
